# %%
import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob

# %%
class TwitterClient(object): 
    ''' 
    Generic Twitter Class for sentiment analysis. 
    '''
    def __init__(self): 
        ''' 
        Class constructor or initialization method. 
        '''
        # keys and tokens from the Twitter Dev Console 
        
        consumer_key = 'XXXXXXXXXXX'
        consumer_secret = 'XXXXXXXXXXXX'
        access_token = 'XXXXXXXXXXXXXXXXXXX'
        access_token_secret = 'XXXXXXXXXXXXXXXXXXs' 
  
        # attempt authentication 
        try: 
            # create OAuthHandler object 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            # set access token and secret 
            self.auth.set_access_token(access_token, access_token_secret) 
            # create tweepy API object to fetch tweets 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 
  
    def clean_tweet(self, tweet): 
        ''' 
        Utility function to clean tweet text by removing links, special characters 
        using simple regex statements. 
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 
  
    def get_tweet_sentiment(self, tweet): 
        ''' 
        Utility function to classify sentiment of passed tweet 
        using textblob's sentiment method 
        '''
        # create TextBlob object of passed tweet text 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        # set sentiment 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'
  
    def get_tweets(self, query, count = 10): 
        ''' 
        Main function to fetch tweets and parse them. 
        '''
        # empty list to store parsed tweets 
        tweets = [] 
  
        try: 
            # call twitter api to fetch tweets 
            fetched_tweets = self.api.search(q = query, count = count) 
  
            # parsing tweets one by one 
            for tweet in fetched_tweets: 
                # empty dictionary to store required params of a tweet 
                parsed_tweet = {} 
  
                # saving text of tweet 
                parsed_tweet['text'] = tweet.text 
                # saving sentiment of tweet 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
  
                # appending parsed tweet to tweets list 
                if tweet.retweet_count > 0: 
                    # if tweet has retweets, ensure that it is appended only once 
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
  
            # return parsed tweets 
            return tweets 
  
        except tweepy.TweepError as e: 
            # print error (if any) 
            print("Error : " + str(e)) 
  
def main(): 
    # creating object of TwitterClient Class 
    api = TwitterClient() 
    # calling function to get tweets 
    tweets = api.get_tweets(query = 'Donald Trump', count = 200) 
  
    # picking positive tweets from tweets 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    # percentage of positive tweets 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    # picking negative tweets from tweets 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    # percentage of negative tweets 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
    # percentage of neutral tweets 
    print("Neutral tweets percentage: {} %".format(100*(len(tweets) - len(ntweets) - len(ptweets))/len(tweets))) 
  
    # printing first 5 positive tweets 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text']) 
  
    # printing first 5 negative tweets 
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text']) 
  
if __name__ == "__main__": 
    # calling main function 
    main()
# Out:
# Positive tweets percentage: 35.2112676056338 %
# Negative tweets percentage: 28.169014084507044 %
# Neutral tweets percentage: 36.61971830985915 %
#
#
# Positive tweets:
# @nytimes @anniekarni is familiar with this approach because it is what @RobbyMook asked her &amp; the other members of… https://t.co/Xmz6ibdmXp
# RT @Goss30Goss: I've heard a lot of dumb shit come out of the mouth of Donald Trump.  This statement 👇is right up there with the most pathe…
# RT @MalcolmNance: Poll: More voters think Donald Trump is a racist than thought George Wallace was in 1968 - CNNPolitics https://t.co/zfdNE…
# RT @kylegriffin1: "For the better part of two decades ... Jeffrey Epstein &amp; Donald Trump swam in the same social pool. They were neighbors…
# @Alyssa_Milano @ChrisMurphyCT Alyssa, take a moment to watch this, this is the REAL Donald Trump. Don't choose igno… https://t.co/dYsqS6L0tj
# RT @PalmerReport: Donald Trump campaign’s latest unofficial surrogate is an alleged murderer  https://t.co/yghfDgdutp
# RT @MichiganGrandm1: Now THIS is very interesting.
# The same people who loved Donald Trump suddenly deem him a racist...
#
# The liberal media…
# RT @kylegriffin1: "More voters think Donald Trump is a racist than thought George Wallace was in 1968." https://t.co/ubZcB4lAwr
# RT @joncoopertweets: Poll: More voters think Donald Trump is a racist than thought George Wallace was in 1968 https://t.co/pvn92169GC
# RT @nowthisnews: ‘Every credible poll that I have seen has me beating Donald Trump.’ — Watch @BernieSanders' best mic-drop moments from the…
#
#
# Negative tweets:
# RT @AmoneyResists: Don Lemon isn’t dumb
#
# Obama wasn’t born in Kenya
#
# Andrew Gillum isn’t a thief
#
# Maxine Waters isn’t low IQ
#
# NFL players a…
# RT @PalmerReport: Donald Trump’s day so far:
#
# - Attacks Don Lemon in racist fashion for calling him a racist
# - Invents this weird new punct…
# RT @HuffPost: Donald Trump made up a story about narrowly avoiding boarding a helicopter that crashed and killed five people, according to…
# RT @DonaldJTrumpJr: Donald Trump Jr. trolls Elizabeth Warren with her fake ancestry during Democratic debate https://t.co/dGtSoMnQOw
# It is not that Donald Trump glaringly eats his dog's facial grease, it's that Richard Spencer rudely punches fruitflies during Tuesdays.
# RT @american2084: @psychdr100 @farmer_garlic #TrumpConcentrationsCamps,
# Epstein, and Mueller have been pushed off the news cycle due to Don…
# RT @AynRandPaulRyan: "Mitch McConnell is a man that knows less about Russia and Russian interference than even Donald Trump, and I know not…
# RT @BretStephensNYT: To anyone who thinks Boris Johnson is remotely like Donald Trump, watch this: https://t.co/ReyBTzJbtS
# RT @shelbel27931214: 🚩🚩POLL TIME!! (im curious)
# CANADIAN RESIDENTS POLL ONLY PLS.
#  Would you trade
# Justine Trudeau for
# Donald Trump
# to l…
# RT @HHooversGhost: #MoscowMitchTraitor
#
# Mitch McConnell is destroying the Senate – and American government | Robert Reich
#  https://t.co/BOE…
